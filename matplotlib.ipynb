# %%
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
x = [1, 2, 3, 4]
y = [10, 20, 25, 30]

# %%
plt.plot(x, y)

# %%
plt.show( )

# %%
plt.plot(x, y, color='green', linestyle='--', marker='o')

# %%
plt.title('My Plot')
# Out:
# Text(0.5, 1.0, 'My Plot')

# %%
plt.xlabel('X-axis')
# Out:
# Text(0.5, 0, 'X-axis')

# %%
plt.ylabel('Y-axis')
# Out:
# Text(0, 0.5, 'Y-axis')

# %%
x = [1, 2, 3]
y1 = [1, 4, 9]
y2 = [1,2,3]

# %%
plt.plot(x, y1, label='Squares')

# %%
plt.plot(x, y2, label='Linear')

# %%
plt.legend( )
# Out:
# C:\Users\benin\AppData\Local\Temp\ipykernel_16916\297178283.py:1: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend( )

# %%
plt.show( )

# %%
categories = ['A', 'B', 'C']
values = [5, 7, 3]

# %%
plt.bar(categories, values)
# Out:
# <BarContainer object of 3 artists>

# %%
plt.show()

# %%
data = [1, 1, 2, 3, 3, 3, 4, 4, 5]

# %%
plt.hist(data, bins=5)
# Out:
# (array([2., 1., 3., 2., 1.]),
#  array([1. , 1.8, 2.6, 3.4, 4.2, 5. ]),
#  <BarContainer object of 5 artists>)

# %%
plt.show()

# %%
x = [1, 2, 3, 4]
y = [10, 20, 25,30]

# %%
plt.scatter(x, y)

# %%
plt.show()

# %%
plt.subplot(1, 2, 1)
# Out:
# <Axes: >

# %%
plt.plot([1, 2, 3], [1, 2, 3])

# %%
plt.subplot(1, 2, 2)
# Out:
# <Axes: >

# %%
plt.plot([1, 2, 3],[3, 2, 1])

# %%
plt.show()

# %%
plt.plot(x, y)

# %%
plt.savefig('plot.png')

# %%
plt.plot(x, y)
plt.savefig('plot.png')
plt.show()
